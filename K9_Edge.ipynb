# %%
# !pip3 install opencv-python requests ultralytics
# Out:
# ...
#   Using cached opencv_python-4.12.0.88-cp37-abi3-macosx_13_0_arm64.whl.metadata (19 kB)
# ...
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# ...
#   Using cached numpy-2.2.6-cp310-cp310-macosx_14_0_arm64.whl.metadata (62 kB)
# ...
#   Using cached charset_normalizer-3.4.4-cp310-cp310-macosx_10_9_universal2.whl.metadata (37 kB)
# ...
#   Using cached idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# ...
#   Using cached urllib3-2.6.2-py3-none-any.whl.metadata (6.6 kB)
# ...
#   Using cached certifi-2025.11.12-py3-none-any.whl.metadata (2.5 kB)
# ...
#   Using cached matplotlib-3.10.8-cp310-cp310-macosx_11_0_arm64.whl.metadata (52 kB)
# ...
#   Using cached pillow-12.0.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (8.8 kB)
# ...
#   Using cached pyyaml-6.0.3-cp310-cp310-macosx_11_0_arm64.whl.metadata (2.4 kB)
# ...
#   Using cached scipy-1.15.3-cp310-cp310-macosx_14_0_arm64.whl.metadata (61 kB)
# ...
#   Using cached contourpy-1.3.2-cp310-cp310-macosx_11_0_arm64.whl.metadata (5.5 kB)
# ...

# %%
import cv2
import time
import os
import requests
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/Users/sidharth/Library/Application Support/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# !cd K9_Deploy && python3 k9_patrol.py

# Requires edge camera files and hardware to run. Shown in the demo
# Out:
# 🚀 Loading K9 Engine from: /Users/sidharth/Documents/ece5831-2025-final-project/K9_Deploy/best.engine
# 📸 Initializing Camera...
# ❌ Failed to open GStreamer pipeline.
